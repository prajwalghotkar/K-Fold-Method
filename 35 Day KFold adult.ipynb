# %%
# KFold and StratifiedKFold

'''Import Libraries '''

import numpy as np
import pandas as pd
import os
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score,StratifiedKFold,StratifiedShuffleSplit,train_test_split,KFold

# %%
os.getcwd()
# Out:
# 'C:\\Users\\HP\\Downloads\\Batch 93 Day35'

# %%
# Load Data Set

os.chdir('C:\\Users\\HP\\Downloads\\Batch 93 Day35\\')
os.getcwd()
# Out:
# 'C:\\Users\\HP\\Downloads\\Batch 93 Day35'

# %%
dataset=pd.read_csv('adult.csv')
display(dataset)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
# Dataset Details

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
dataset.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
# Check for Null Values

dataset.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
# Convert Gender Male to 0 and Female to 1

dataset['gender']=dataset['gender'].map({'Male':0,'Female':1})
display(dataset)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black       0
# ...

# %%
dataset.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender              int64
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
# Covert marital - status 0 and 1

dataset['marital-status']=dataset['marital-status'].replace(['Never-married','Divorced','Separated','Widowed'],0)
dataset['marital-status']=dataset['marital-status'].replace(['Married-AF-spouse','Married-civ-spouse','Married-spouse-absent'],1)
display(dataset)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#        marital-status         occupation relationship   race  gender  \
# 0                   0  Machine-op-inspct    Own-child  Black       0
# ...

# %%
# Convert marital-status to Integer

dataset['marital-status']=dataset['marital-status'].astype(int)
dataset.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status      int32
# occupation         object
# relationship       object
# race               object
# gender              int64
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
dataset
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#        marital-status         occupation relationship   race  gender  \
# 0                   0  Machine-op-inspct    Own-child  Black       0
# ...

# %%
# remove columns which are not important

dataset.drop(labels=['workclass','education','occupation','relationship','race','native-country'],axis=1,inplace=True)
display(dataset)
# Out:
#        age  fnlwgt  educational-num  marital-status  gender  capital-gain  \
# 0       25  226802                7               0       0             0
# 1       38   89814                9               1       0             0
# 2       28  336951               12               1       0             0
# 3       44  160323               10               1       0          7688
# 4       18  103497               10               0       1             0
# ...    ...     ...              ...             ...     ...           ...
# 48837   27  257302               12               1       1             0
# 48838   40  154374                9               1       0             0
# 48839   58  151910                9               0       1             0
# 48840   22  201490                9               0       0             0
# 48841   52  287927                9               1       1         15024
#
#        capital-loss  hours-per-week income
# ...

# %%
# Create Y 

y=dataset['income']
y
# Out:
# 0        <=50K
# 1        <=50K
# 2         >50K
# 3         >50K
# 4        <=50K
#          ...
# 48837    <=50K
# 48838     >50K
# 48839    <=50K
# 48840    <=50K
# 48841     >50K
# Name: income, Length: 48842, dtype: object

# %%
# Dataset as X

dataset=dataset.drop('income',axis=1)
display(dataset)
# Out:
#        age  fnlwgt  educational-num  marital-status  gender  capital-gain  \
# 0       25  226802                7               0       0             0
# 1       38   89814                9               1       0             0
# 2       28  336951               12               1       0             0
# 3       44  160323               10               1       0          7688
# 4       18  103497               10               0       1             0
# ...    ...     ...              ...             ...     ...           ...
# 48837   27  257302               12               1       1             0
# 48838   40  154374                9               1       0             0
# 48839   58  151910                9               0       1             0
# 48840   22  201490                9               0       0             0
# 48841   52  287927                9               1       1         15024
#
#        capital-loss  hours-per-week
# 0                 0              40
# ...

# %%
# Train Test Split

x_train,x_test,y_train,y_test=train_test_split(dataset,y,test_size=0.2,random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (39073, 8)
# (9769, 8)
# (39073,)
# (9769,)

# %%
# Create the Model

models=[]
models.append(('LR',LogisticRegression()))
models.append(('KNN',KNeighborsClassifier()))
print(models)
# Out:
# [('LR', LogisticRegression()), ('KNN', KNeighborsClassifier())]

# %%
# Create Logistic Regression in the Normal way

LR=LogisticRegression()
LR.fit(x_train,y_train)
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Prediction

y_pred=LR.predict(x_test)
y_pred
# Out:
# array(['<=50K', '<=50K', '>50K', ..., '<=50K', '<=50K', '<=50K'],
#       dtype=object)

# %%
# Accuracy

from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8040741119868974

# %%
# Display Unique Values

print(y_test.value_counts())
print(pd.DataFrame(y_pred).value_counts())
# Out:
# income
# <=50K    7479
# >50K     2290
# Name: count, dtype: int64
# <=50K    8909
# >50K      860
# Name: count, dtype: int64

# %%
for name,model in models:
    print(name,model)
# Out:
# LR LogisticRegression()
# KNN KNeighborsClassifier()

# %%
# Implement K Fold 10 - Fold
result=dict()
for name,model in models:
    kfold=KFold(n_splits=10)
    cv_results=cross_val_score(model,x_train,y_train,cv=kfold,scoring='accuracy')
    result[name]=(cv_results,cv_results.mean(),cv_results.std())
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
# Display Accuracy

for key,value in result.items():
    print('Model Name:',key,'\n Individual Accuracy:\n',value[0],'\nMean:',value[1],'\nSTD:',value[2],'\n')
# Out:
# Model Name: LR
#  Individual Accuracy:
#  [0.80706244 0.79657114 0.79682702 0.79626312 0.78653698 0.79805477
#  0.79882263 0.80394164 0.78704889 0.78525723]
# Mean: 0.7956385856003673
# STD: 0.006946134662820671
#
# Model Name: KNN
#  Individual Accuracy:
#  [0.77763562 0.78377687 0.77379734 0.78346557 0.76631687 0.77962631
#  0.76990018 0.79498336 0.76119785 0.76785257]
# Mean: 0.7758552544196059
# STD: 0.009557746839878192

# %%
# Implement Stratified KFold 10 - Fold
skresult=dict()
for name,model in models:
    skfold=StratifiedKFold(n_splits=10)
    skcv_results=cross_val_score(model,x_train,y_train,cv=skfold,scoring='accuracy')
    skresult[name]=(skcv_results,skcv_results.mean(),skcv_results.std())
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
# Display Accuracy

for pajju,samu in skresult.items():
    print('Model Name:',pajju,'\n Individual Accuracy:\n',samu[0],'\nMean:',samu[1],'\nSTD:',samu[2],'\n')
# Out:
# Model Name: LR
#  Individual Accuracy:
#  [0.79631525 0.80271238 0.78812692 0.80035833 0.79242385 0.79933453
#  0.79242385 0.79498336 0.79447146 0.79523931]
# Mean: 0.7956389261695735
# STD: 0.004067892991921202
#
# Model Name: KNN
#  Individual Accuracy:
#  [0.77251791 0.78480041 0.77507677 0.78244177 0.77220374 0.78039416
#  0.76554901 0.78218582 0.76657282 0.7750192 ]
# Mean: 0.775676160862887
# STD: 0.006339666407181896

# %%
# Implement Stratified KFold 10 - Fold
sskresult=dict()
for name,model in models:
    sskfold=StratifiedShuffleSplit(n_splits=10)
    sskcv_results=cross_val_score(model,x_train,y_train,cv=sskfold,scoring='accuracy')
    sskresult[name]=(sskcv_results,sskcv_results.mean(),sskcv_results.std())
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
# Display Accuracy

for pajju,samu in sskresult.items():
    print('Model Name:',pajju,'\n Individual Accuracy:\n',samu[0],'\nMean:',samu[1],'\nSTD:',samu[2],'\n')
# Out:
# Model Name: LR
#  Individual Accuracy:
#  [0.80399181 0.78991812 0.79452405 0.79119754 0.80322416 0.78966223
#  0.79912999 0.79733879 0.78940635 0.79989765]
# Mean: 0.7958290685772774
# STD: 0.005370484552235334
#
# Model Name: KNN
#  Individual Accuracy:
#  [0.77712385 0.77021494 0.7814739  0.77558854 0.77302968 0.77251791
#  0.77840328 0.77584442 0.77354145 0.76484135]
# Mean: 0.7742579324462641
# STD: 0.004379752895667291

# %%
# OK Prajwal
